# %% [markdown]
# <a href="https://colab.research.google.com/github/graciemawan/22_339_BARC-S/blob/main/22_339_BARC-S.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
STUDENT_ID = "22/339/BARC-S"
COHORT = "CML3112"

# %%
print("Hello from CML3112")
proof_sum = 2 + 2
print(proof_sum)
# Out:
# Hello from CML3112
# 4

# %%
readings = 12

# %%
readings = readings + 5
print(readings)
# Out:
# 17

# %% [markdown]
# After running the previous cell three times, I noticed that the number or readings kept changing. The initial number was 17 and when I ran it again, it added 5 to 17 making it 22 and I ran it again and it added 5 to 22 making it 27 and I ran it again and it added another 5 to 27 making it 32

# %%
import csv
with open("site_inspection_log.csv", newline="") as f:
    rows = list(csv.DictReader(f))
print(len(rows))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_5035/1480748277.py in <cell line: 0>()
#       1 import csv
# ----> 2 with open("site_inspection_log.csv", newline="") as f:
#       3     rows = list(csv.DictReader(f))
#       4 print(len(rows))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'site_inspection_log.csv'
